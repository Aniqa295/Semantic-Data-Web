# %%
import plotly.express as px
import plotly.graph_objs as go
from jupyter_dash import JupyterDash
from dash.dependencies import Input, Output, State
import plotly.express as px
from jupyter_dash import JupyterDash
from dash.dependencies import Input, Output, State
import dash
import pandas as pd
import import_ipynb

from lat_lon_parser import parse

from ipynb.fs.full.MainApp import app

# %%
#---------------------------------------------------Charts Function--------------------------------------------------------------
def gen_map_function(n_clicks, jsonified_ResultListdataframe):
    
    if n_clicks > 0:
       
        ResultListdataframe = pd.read_json(jsonified_ResultListdataframe, orient='split')
        
        if 'lon' in ResultListdataframe.columns: 
            
            fig = go.Figure()
        
        
            fig.add_trace(go.Scattergeo(
                                lat = ResultListdataframe['lat'],
                                lon = ResultListdataframe['lon'],
                                text = ResultListdataframe['lon'].astype(str),
                                mode = 'markers',
                                #locationmode = "ISO-3"                           
                )
                         )        
            
            
                    
            buttonlist = []
            for col in ResultListdataframe.columns:
                    buttonlist.append(
                        dict(
                            args=['text', ResultListdataframe[col].astype(str)],
                            label=str(col),
                            method='restyle', 
                            )
                    )
                    
            scope_options = ["world", "europe"]
            buttonlist_scope= []
            for option in scope_options:
                buttonlist_scope.append(
                    dict(
                        args = ['geo.scope', str(option)],
                        label = str(option),
                        method = 'restyle',
                )
            )
            
                    
            fig.update_geos(
                visible=True,
                resolution=110,
                showcountries=True, countrycolor="Black",
                showsubunits=True, subunitcolor="Blue",
                scope="world",

                
          )

            fig.update_layout(
                    autosize=True,
                    updatemenus=[
                        dict(buttons=buttonlist,
                            direction="down",
                            pad={"r": 10, "t": 10},
                            showactive=True,
                            x=-0.9,
                            xanchor="left",
                            y=0.90,
                            yanchor="top"
                                ), 
                        
                        
                        
                        dict(buttons=buttonlist_scope,
                            direction="down",
                            pad={"r": 10, "t": 10},
                            showactive=True,
                            x=-0.9,
                            xanchor="left",
                            y=0.60,
                            yanchor="top"
                                ), 
                            ],

                        )
            
            fig.update_layout(height=800)
            
           


            
        else:
            print('No Coordinates')#pop up no coordinate
            return { },{'display': 'none'}


        return fig,{'display': 'block'}

    return { },{'display': 'none'}

# %%
#---------------------------------------------------Charts Callback--------------------------------------------------------------
@app.callback(
    [Output("map", "figure"), Output('result-map', 'style')],
    [Input("submit-btn", "n_clicks"),
    Input("intermediate-value", "children"),
    ],
)
def gen_map(n_clicks, jsonified_ResultListdataframe):
    return gen_map_function(n_clicks, jsonified_ResultListdataframe)
    
#---------------------------------------------------Charts Compare Callback--------------------------------------------------------------
@app.callback(
    [Output("map2", "figure"), Output('result-map2', 'style')],
    [Input("compare-btn", "n_clicks"),
    Input("intermediate-value2", "children"),
    ],
)
def gen_map(n_clicks, jsonified_ResultListdataframe):
    return gen_map_function(n_clicks, jsonified_ResultListdataframe)

# %% [raw]
#
#             #fig.update_geos(scope='world')
#
#
# #            location_options = ["ISO-3", "USA-states"]
# #            buttonlist_location= []
# #            for option in location_options:
# #                print(option)
# #                buttonlist_location.append(
# #                    dict(
# #                        args = ['locationmode', str(option)],
# #                        label = str(option),
# #                        method = 'restyle',
# #                )
# #            )
#
#
#
#
#
# #                        dict(buttons=buttonlist_location,
# #                                direction="down",
# #                                pad={"r": 10, "t": 10},
# #                                showactive=True,
# #                                x=-0.9,
# #                                xanchor="left",
# #                                y=0.60,
# #                                yanchor="top"
# #                                    ),
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# #            fig = go.Figure(data=go.Scattergeo(
# #                            lat = ResultListdataframe['lat'],
# #                            lon = ResultListdataframe['lon'],
# #                            text = ResultListdataframe['name'].astype(str),
# #                            mode='markers'
# #
# #                ))
#
#
#
#             fig.update_geos(fitbounds="locations", visible=False)
#
#             fig.update_geos(
#                 visible=False, resolution=50,
#                 showcountries=True, countrycolor="Black",
#                 showsubunits=True, subunitcolor="Blue"
#             )
#             fig.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})

# %% [raw]
#             #fig = go.Figure()
#
#             #fig = go.Figure(go.Scattermapbox(
#             #                lat=ResultListdataframe['lat'],
#             #                lon=ResultListdataframe['lon'],
#             #                mode='markers',
#             #                marker=go.scattermapbox.Marker(
#             #                        size=9
#             #                ),
#             #                text=ResultListdataframe['name'],
#             #            ))
#
#            # fig.update_layout(mapbox_style="open-street-map")
#
#
#
#
# #            buttonlist = []
# #            for col in ResultListdataframe.columns:
# #                  buttonlist.append(
# #                        dict(
# #                        args = ['hoverlabel',[ResultListdataframe[str(col)]]],
# #                        label = str(col),
# #                        method='update'
# #                    )
# #                  )
#
# #            fig.update_layout(
# #                updatemenus=[
# #                    dict(buttons=buttonlist,
# #                    direction="down",
# #                    pad={"r": 10, "t": 10},
# #                    showactive=True,
# #                    x=-1.5,
# #                    xanchor="left",
# #                    y=1,
#  #                   yanchor="top"
# #
# #                        ),
# #                ]
# #            )
#
#
#
#
#
#
# #            fig.add_trace(px.scatter_mapbox(
# #                                lon =  ResultListdataframe['lon'],
# #                                lat = ResultListdataframe['lat'],
# #                                mode = 'markers',
# #                                fillcolor = 'red',
# #
# #                               ))
